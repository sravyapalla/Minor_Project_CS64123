# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import f1_score, confusion_matrix, classification_report
from sklearn.utils import shuffle, class_weight
from sklearn.feature_extraction import FeatureHasher
import os

# Set seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Load dataset
file_path = r"C:\Users\shravya\PycharmProjects\minor\DDOS Dataset.csv"
print("Loading dataset...")
df = pd.read_csv(file_path)
print(f"Original dataset shape: {df.shape}")
# Out:
# Loading dataset...
# Original dataset shape: (15462150, 26)

# %%
# Drop unused or problematic columns
df = df.drop(columns=['flow_id', 'ip_src', 'ip_dst'], errors='ignore')
df.replace([np.inf, -np.inf], np.nan, inplace=True)
df.dropna(inplace=True)

# Drop constant columns
constant_cols = [col for col in df.columns if df[col].nunique() == 1]
df.drop(columns=constant_cols, inplace=True)

# Feature hashing (if needed)
high_card_cols = ['flow_id', 'ip_src']
existing_high_card_cols = [col for col in high_card_cols if col in df.columns]
if existing_high_card_cols:
    hasher = FeatureHasher(n_features=5, input_type='string')
    hashed_features = hasher.transform(df[existing_high_card_cols].astype(str).to_dict('records'))
    df_hashed = pd.DataFrame(hashed_features.toarray(), columns=[f'hash_{i}' for i in range(5)])
    df.drop(columns=existing_high_card_cols, inplace=True)
    df = pd.concat([df, df_hashed], axis=1)

# Scale numeric features
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns.drop('label')
scaler = MinMaxScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Encode target if categorical
if df['label'].dtype == 'object':
    le = LabelEncoder()
    df['label'] = le.fit_transform(df['label'])

# Correlation-based feature selection
correlation_with_target = df.corr()['label'].drop('label')
selected_features = correlation_with_target[abs(correlation_with_target) >= 0.1].index.tolist()
df = df[selected_features + ['label']]
print(f"Selected features: {selected_features}")

# Shuffle and split dataset
df = shuffle(df, random_state=42)
X = df.drop(columns=['label']).values
y = df['label'].values

# Stratified train-test split
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in sss.split(X, y):
    X_train, X_test = X[train_idx], X[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

# Reshape data for LSTM (1 timestep)
X_train_lstm = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_lstm = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Class weights for imbalance
class_weights = class_weight.compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(enumerate(class_weights))
print(f"Class weights: {class_weight_dict}")


from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    Input, LSTM, Dense, Dropout,
    BatchNormalization, Flatten, Concatenate
)
from tensorflow.keras import regularizers, constraints
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# --- 1) Define the new hybrid model without any added noise ---
inp = Input(shape=(1, X_train.shape[1]))

# LSTM branch: very small + heavy reg
lstm = LSTM(
    16,
    return_sequences=False,
    kernel_regularizer=regularizers.l2(0.02),
    kernel_constraint=constraints.max_norm(3)
)(inp)
lstm = Dropout(0.5)(lstm)
lstm = Dense(
    8,
    activation='relu',
    kernel_regularizer=regularizers.l2(0.02),
    kernel_constraint=constraints.max_norm(3)
)(lstm)

# ANN branch: small + heavy reg
flat = Flatten()(inp)
ann = Dense(
    32,
    activation='relu',
    kernel_regularizer=regularizers.l2(0.02),
    kernel_constraint=constraints.max_norm(3)
)(flat)
ann = BatchNormalization()(ann)
ann = Dropout(0.5)(ann)
ann = Dense(
    16,
    activation='relu',
    kernel_regularizer=regularizers.l2(0.02),
    kernel_constraint=constraints.max_norm(3)
)(ann)

# Merge branches
merged = Concatenate()([lstm, ann])
merged = Dense(
    8,
    activation='relu',
    kernel_regularizer=regularizers.l2(0.02),
    kernel_constraint=constraints.max_norm(3)
)(merged)
merged = Dropout(0.4)(merged)

out = Dense(1, activation='sigmoid')(merged)

model = Model(inputs=inp, outputs=out)

# --- 2) Compile with a lower LR ---
model.compile(
    optimizer=Adam(learning_rate=5e-4),
    loss='binary_crossentropy',
    metrics=['accuracy',
             tf.keras.metrics.Precision(name='precision'),
             tf.keras.metrics.Recall(name='recall')]
)

# --- 3) Callbacks for overfitting control ---
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=2,
    restore_best_weights=True,
    verbose=1
)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=1,
    min_lr=1e-6,
    verbose=1
)

# --- 4) Train for fewer epochs ---
# --- Model Training ---
history = model.fit(
    X_train_lstm, y_train,
    epochs=5,
    batch_size=256,
    validation_data=(X_test_lstm, y_test),
    class_weight=class_weight_dict,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# --- Evaluate on Training Set ---
train_loss, train_accuracy, train_precision, train_recall = model.evaluate(X_train_lstm, y_train, verbose=0)
y_train_pred = (model.predict(X_train_lstm, verbose=0) > 0.5).astype("int32")
train_f1 = f1_score(y_train, y_train_pred)
train_conf_matrix = confusion_matrix(y_train, y_train_pred)

print("\n✅ TRAIN SET EVALUATION")
print(f"Train Loss: {train_loss:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Train Precision: {train_precision:.4f}")
print(f"Train Recall: {train_recall:.4f}")
print(f"Train F1-Score: {train_f1:.4f}")
print("\nTrain Confusion Matrix:")
print(train_conf_matrix)

# --- Evaluate on Test Set ---
test_loss, test_accuracy, test_precision, test_recall = model.evaluate(X_test_lstm, y_test, verbose=0)
y_test_pred = (model.predict(X_test_lstm, verbose=0) > 0.5).astype("int32")
test_f1 = f1_score(y_test, y_test_pred)
test_conf_matrix = confusion_matrix(y_test, y_test_pred)

print("\n✅ TEST SET EVALUATION")
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test Precision: {test_precision:.4f}")
print(f"Test Recall: {test_recall:.4f}")
print(f"Test F1-Score: {test_f1:.4f}")
print("\nTest Confusion Matrix:")
print(test_conf_matrix)
# Out:
# Selected features: ['timestamp', 'tp_dst', 'ip_proto', 'flow_duration_sec', 'packet_count', 'byte_count', 'packet_count_per_second', 'byte_count_per_second']
# Class weights: {0: np.float64(1.4707587507339948), 1: np.float64(0.757530513952075)}
# Epoch 1/5
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 15s 2ms/step - accuracy: 0.9103 - loss: 0.5296 - precision: 0.9149 - recall: 0.9503 - val_accuracy: 0.9682 - val_loss: 0.1761 - val_precision: 0.9541 - val_recall: 0.9999 - learning_rate: 5.0000e-04
# Epoch 2/5
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 13s 2ms/step - accuracy: 0.9550 - loss: 0.2249 - precision: 0.9395 - recall: 0.9958 - val_accuracy: 0.9690 - val_loss: 0.1587 - val_precision: 0.9552 - val_recall: 0.9999 - learning_rate: 5.0000e-04
# Epoch 3/5
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 22s 3ms/step - accuracy: 0.9558 - loss: 0.2114 - precision: 0.9409 - recall: 0.9955 - val_accuracy: 0.9696 - val_loss: 0.1540 - val_precision: 0.9561 - val_recall: 0.9999 - learning_rate: 5.0000e-04
# Epoch 4/5
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 31s 4ms/step - accuracy: 0.9567 - loss: 0.2046 - precision: 0.9417 - recall: 0.9960 - val_accuracy: 0.9696 - val_loss: 0.1493 - val_precision: 0.9560 - val_recall: 0.9999 - learning_rate: 5.0000e-04
# Epoch 5/5
# 8330/8337 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9567 - loss: 0.2015 - precision: 0.9419 - recall: 0.9957
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 8337/8337 ━━━━━━━━━━━━━━━━━━━━ 29s 3ms/step - accuracy: 0.9567 - loss: 0.2015 - precision: 0.9419 - recall: 0.9957 - val_accuracy: 0.9685 - val_loss: 0.1504 - val_precision: 0.9544 - val_recall: 1.0000 - learning_rate: 5.0000e-04
# Restoring model weights from the end of the best epoch: 4.
#
# ✅ TRAIN SET EVALUATION
# Train Loss: 0.1482
# Train Accuracy: 0.9701
# Train Precision: 0.9568
# Train Recall: 0.9999
# Train F1-Score: 0.9779
#
# Train Confusion Matrix:
# [[ 661885   63597]
#  [    118 1408418]]
#
# ✅ TEST SET EVALUATION
# Test Loss: 0.1493
# Test Accuracy: 0.9696
# Test Precision: 0.9560
# Test Recall: 0.9999
# Test F1-Score: 0.9775
#
# Test Confusion Matrix:
# [[165172  16199]
#  [    24 352110]]

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix, f1_score

# --- Combine Train and Test Data ---
X_combined = np.concatenate((X_train, X_test), axis=0)
y_combined = np.concatenate((y_train, y_test), axis=0)

# --- FGSM Attack Function ---
def fgsm_attack(model, X, y, epsilon=0.1, batch_size=1024):
    X_adv = np.zeros_like(X)
    for i in range(0, len(X), batch_size):
        batch_end = min(i + batch_size, len(X))
        X_batch = tf.convert_to_tensor(X[i:batch_end], dtype=tf.float32)
        y_batch = y[i:batch_end]
        y_batch = tf.expand_dims(y_batch, axis=-1)

        # Reshape for LSTM
        X_batch_reshaped = tf.reshape(X_batch, (-1, 1, X_batch.shape[1]))

        with tf.GradientTape() as tape:
            tape.watch(X_batch_reshaped)
            predictions = model(X_batch_reshaped, training=False)
            loss = tf.keras.losses.binary_crossentropy(y_batch, predictions)
            loss = tf.reduce_mean(loss)

        gradient = tape.gradient(loss, X_batch_reshaped)
        signed_grad = tf.sign(gradient)
        X_adv_batch = X_batch_reshaped + epsilon * signed_grad
        X_adv_batch = tf.clip_by_value(X_adv_batch, 0, 1)

        X_adv[i:batch_end] = X_adv_batch.numpy().reshape(X_adv_batch.shape[0], -1)
        print(f"Processed batch {i // batch_size + 1}/{(len(X) // batch_size) + 1}")
    return X_adv

# --- Generate Adversarial Examples ---
print("\nGenerating FGSM adversarial examples for the entire combined dataset...")
X_combined_adv = fgsm_attack(model, X_combined, y_combined, epsilon=0.1, batch_size=1024)
print(f"Shape of X_combined_adv: {X_combined_adv.shape}")

# --- Save to CSV ---
pd.DataFrame(X_combined_adv).to_csv("X_combined_adv.csv", index=False)
print("Adversarial samples saved to 'X_combined_adv.csv'.")

# --- Reshape for Hybrid ANN + LSTM model ---
X_combined_adv_lstm = X_combined_adv.reshape((X_combined_adv.shape[0], 1, X_combined_adv.shape[1]))

# --- Evaluate the Hybrid Model on Adversarial Samples ---
print("\n📊 Evaluating Hybrid ANN + LSTM Model on Adversarial Samples...")
adv_loss, adv_accuracy, adv_precision, adv_recall = model.evaluate(X_combined_adv_lstm, y_combined, verbose=0)
y_adv_pred = (model.predict(X_combined_adv_lstm, verbose=0) > 0.5).astype("int32")
adv_f1 = f1_score(y_combined, y_adv_pred)
adv_cm = confusion_matrix(y_combined, y_adv_pred)

# --- Print Results ---
print("\n✅ EVALUATION ON ADVERSARIAL SAMPLES")
print(f"Adversarial Loss       : {adv_loss:.4f}")
print(f"Adversarial Accuracy   : {adv_accuracy:.4f}")
print(f"Adversarial Precision  : {adv_precision:.4f}")
print(f"Adversarial Recall     : {adv_recall:.4f}")
print(f"Adversarial F1-Score   : {adv_f1:.4f}")
print("Adversarial Confusion Matrix:")
print(adv_cm)
# Out:
# Generating FGSM adversarial examples for the entire combined dataset...
# Processed batch 1/2606
# Processed batch 2/2606
# Processed batch 3/2606
# Processed batch 4/2606
# Processed batch 5/2606
# Processed batch 6/2606
# Processed batch 7/2606
# Processed batch 8/2606
# Processed batch 9/2606
# Processed batch 10/2606
# Processed batch 11/2606
# Processed batch 12/2606
# Processed batch 13/2606
# Processed batch 14/2606
# Processed batch 15/2606
# Processed batch 16/2606
# Processed batch 17/2606
# Processed batch 18/2606
# Processed batch 19/2606
# Processed batch 20/2606
# Processed batch 21/2606
# Processed batch 22/2606
# Processed batch 23/2606
# Processed batch 24/2606
# Processed batch 25/2606
# Processed batch 26/2606
# Processed batch 27/2606
# Processed batch 28/2606
# Processed batch 29/2606
# Processed batch 30/2606
# Processed batch 31/2606
# Processed batch 32/2606
# Processed batch 33/2606
# Processed batch 34/2606
# Processed batch 35/2606
# Processed batch 36/2606
# Processed batch 37/2606
# Processed batch 38/2606
# Processed batch 39/2606
# Processed batch 40/2606
# Processed batch 41/2606
# Processed batch 42/2606
# Processed batch 43/2606
# Processed batch 44/2606
# Processed batch 45/2606
# Processed batch 46/2606
# Processed batch 47/2606
# Processed batch 48/2606
# Processed batch 49/2606
# Processed batch 50/2606
# Processed batch 51/2606
# Processed batch 52/2606
# Processed batch 53/2606
# Processed batch 54/2606
# Processed batch 55/2606
# Processed batch 56/2606
# Processed batch 57/2606
# Processed batch 58/2606
# Processed batch 59/2606
# Processed batch 60/2606
# Processed batch 61/2606
# Processed batch 62/2606
# Processed batch 63/2606
# Processed batch 64/2606
# Processed batch 65/2606
# Processed batch 66/2606
# Processed batch 67/2606
# Processed batch 68/2606
# Processed batch 69/2606
# Processed batch 70/2606
# Processed batch 71/2606
# Processed batch 72/2606
# Processed batch 73/2606
# Processed batch 74/2606
# Processed batch 75/2606
# Processed batch 76/2606
# Processed batch 77/2606
# Processed batch 78/2606
# Processed batch 79/2606
# Processed batch 80/2606
# Processed batch 81/2606
# Processed batch 82/2606
# Processed batch 83/2606
# Processed batch 84/2606
# Processed batch 85/2606
# Processed batch 86/2606
# Processed batch 87/2606
# Processed batch 88/2606
# Processed batch 89/2606
# Processed batch 90/2606
# Processed batch 91/2606
# Processed batch 92/2606
# Processed batch 93/2606
# Processed batch 94/2606
# Processed batch 95/2606
# Processed batch 96/2606
# Processed batch 97/2606
# Processed batch 98/2606
# Processed batch 99/2606
# Processed batch 100/2606
# Processed batch 101/2606
# Processed batch 102/2606
# Processed batch 103/2606
# Processed batch 104/2606
# Processed batch 105/2606
# Processed batch 106/2606
# Processed batch 107/2606
# Processed batch 108/2606
# Processed batch 109/2606
# Processed batch 110/2606
# Processed batch 111/2606
# Processed batch 112/2606
# Processed batch 113/2606
# Processed batch 114/2606
# Processed batch 115/2606
# Processed batch 116/2606
# Processed batch 117/2606
# Processed batch 118/2606
# Processed batch 119/2606
# Processed batch 120/2606
# Processed batch 121/2606
# Processed batch 122/2606
# Processed batch 123/2606
# Processed batch 124/2606
# Processed batch 125/2606
# Processed batch 126/2606
# Processed batch 127/2606
# Processed batch 128/2606
# Processed batch 129/2606
# Processed batch 130/2606
# Processed batch 131/2606
# Processed batch 132/2606
# Processed batch 133/2606
# Processed batch 134/2606
# Processed batch 135/2606
# Processed batch 136/2606
# Processed batch 137/2606
# Processed batch 138/2606
# Processed batch 139/2606
# Processed batch 140/2606
# Processed batch 141/2606
# Processed batch 142/2606
# Processed batch 143/2606
# Processed batch 144/2606
# Processed batch 145/2606
# Processed batch 146/2606
# Processed batch 147/2606
# Processed batch 148/2606
# Processed batch 149/2606
# Processed batch 150/2606
# Processed batch 151/2606
# Processed batch 152/2606
# Processed batch 153/2606
# Processed batch 154/2606
# Processed batch 155/2606
# Processed batch 156/2606
# Processed batch 157/2606
# Processed batch 158/2606
# Processed batch 159/2606
# Processed batch 160/2606
# Processed batch 161/2606
# Processed batch 162/2606
# Processed batch 163/2606
# Processed batch 164/2606
# Processed batch 165/2606
# Processed batch 166/2606
# Processed batch 167/2606
# Processed batch 168/2606
# Processed batch 169/2606
# Processed batch 170/2606
# Processed batch 171/2606
# Processed batch 172/2606
# Processed batch 173/2606
# Processed batch 174/2606
# Processed batch 175/2606
# Processed batch 176/2606
# Processed batch 177/2606
# Processed batch 178/2606
# Processed batch 179/2606
# Processed batch 180/2606
# Processed batch 181/2606
# Processed batch 182/2606
# Processed batch 183/2606
# Processed batch 184/2606
# Processed batch 185/2606
# Processed batch 186/2606
# Processed batch 187/2606
# Processed batch 188/2606
# Processed batch 189/2606
# Processed batch 190/2606
# Processed batch 191/2606
# Processed batch 192/2606
# Processed batch 193/2606
# Processed batch 194/2606
# Processed batch 195/2606
# Processed batch 196/2606
# Processed batch 197/2606
# Processed batch 198/2606
# Processed batch 199/2606
# Processed batch 200/2606
# Processed batch 201/2606
# Processed batch 202/2606
# Processed batch 203/2606
# Processed batch 204/2606
# Processed batch 205/2606
# Processed batch 206/2606
# Processed batch 207/2606
# Processed batch 208/2606
# Processed batch 209/2606
# Processed batch 210/2606
# Processed batch 211/2606
# Processed batch 212/2606
# Processed batch 213/2606
# Processed batch 214/2606
# Processed batch 215/2606
# Processed batch 216/2606
# Processed batch 217/2606
# Processed batch 218/2606
# Processed batch 219/2606
# Processed batch 220/2606
# Processed batch 221/2606
# Processed batch 222/2606
# Processed batch 223/2606
# Processed batch 224/2606
# Processed batch 225/2606
# Processed batch 226/2606
# Processed batch 227/2606
# Processed batch 228/2606
# Processed batch 229/2606
# Processed batch 230/2606
# Processed batch 231/2606
# Processed batch 232/2606
# Processed batch 233/2606
# Processed batch 234/2606
# Processed batch 235/2606
# Processed batch 236/2606
# Processed batch 237/2606
# Processed batch 238/2606
# Processed batch 239/2606
# Processed batch 240/2606
# Processed batch 241/2606
# Processed batch 242/2606
# Processed batch 243/2606
# Processed batch 244/2606
# Processed batch 245/2606
# Processed batch 246/2606
# Processed batch 247/2606
# Processed batch 248/2606
# Processed batch 249/2606
# Processed batch 250/2606
# Processed batch 251/2606
# Processed batch 252/2606
# Processed batch 253/2606
# Processed batch 254/2606
# Processed batch 255/2606
# Processed batch 256/2606
# Processed batch 257/2606
# Processed batch 258/2606
# Processed batch 259/2606
# Processed batch 260/2606
# Processed batch 261/2606
# Processed batch 262/2606
# Processed batch 263/2606
# Processed batch 264/2606
# Processed batch 265/2606
# Processed batch 266/2606
# Processed batch 267/2606
# Processed batch 268/2606
# Processed batch 269/2606
# Processed batch 270/2606
# Processed batch 271/2606
# Processed batch 272/2606
# Processed batch 273/2606
# Processed batch 274/2606
# Processed batch 275/2606
# Processed batch 276/2606
# Processed batch 277/2606
# Processed batch 278/2606
# Processed batch 279/2606
# Processed batch 280/2606
# Processed batch 281/2606
# Processed batch 282/2606
# Processed batch 283/2606
# Processed batch 284/2606
# Processed batch 285/2606
# Processed batch 286/2606
# Processed batch 287/2606
# Processed batch 288/2606
# Processed batch 289/2606
# Processed batch 290/2606
# Processed batch 291/2606
# Processed batch 292/2606
# Processed batch 293/2606
# Processed batch 294/2606
# Processed batch 295/2606
# Processed batch 296/2606
# Processed batch 297/2606
# Processed batch 298/2606
# Processed batch 299/2606
# Processed batch 300/2606
# Processed batch 301/2606
# Processed batch 302/2606
# Processed batch 303/2606
# Processed batch 304/2606
# Processed batch 305/2606
# Processed batch 306/2606
# Processed batch 307/2606
# Processed batch 308/2606
# Processed batch 309/2606
# Processed batch 310/2606
# Processed batch 311/2606
# Processed batch 312/2606
# Processed batch 313/2606
# Processed batch 314/2606
# Processed batch 315/2606
# Processed batch 316/2606
# Processed batch 317/2606
# Processed batch 318/2606
# Processed batch 319/2606
# Processed batch 320/2606
# Processed batch 321/2606
# Processed batch 322/2606
# Processed batch 323/2606
# Processed batch 324/2606
# Processed batch 325/2606
# Processed batch 326/2606
# Processed batch 327/2606
# Processed batch 328/2606
# Processed batch 329/2606
# Processed batch 330/2606
# Processed batch 331/2606
# Processed batch 332/2606
# Processed batch 333/2606
# Processed batch 334/2606
# Processed batch 335/2606
# Processed batch 336/2606
# Processed batch 337/2606
# Processed batch 338/2606
# Processed batch 339/2606
# Processed batch 340/2606
# Processed batch 341/2606
# Processed batch 342/2606
# Processed batch 343/2606
# Processed batch 344/2606
# Processed batch 345/2606
# Processed batch 346/2606
# Processed batch 347/2606
# Processed batch 348/2606
# Processed batch 349/2606
# Processed batch 350/2606
# Processed batch 351/2606
# Processed batch 352/2606
# Processed batch 353/2606
# Processed batch 354/2606
# Processed batch 355/2606
# Processed batch 356/2606
# Processed batch 357/2606
# Processed batch 358/2606
# Processed batch 359/2606
# Processed batch 360/2606
# Processed batch 361/2606
# Processed batch 362/2606
# Processed batch 363/2606
# Processed batch 364/2606
# Processed batch 365/2606
# Processed batch 366/2606
# Processed batch 367/2606
# Processed batch 368/2606
# Processed batch 369/2606
# Processed batch 370/2606
# Processed batch 371/2606
# Processed batch 372/2606
# Processed batch 373/2606
# Processed batch 374/2606
# Processed batch 375/2606
# Processed batch 376/2606
# Processed batch 377/2606
# Processed batch 378/2606
# Processed batch 379/2606
# Processed batch 380/2606
# Processed batch 381/2606
# Processed batch 382/2606
# Processed batch 383/2606
# Processed batch 384/2606
# Processed batch 385/2606
# Processed batch 386/2606
# Processed batch 387/2606
# Processed batch 388/2606
# Processed batch 389/2606
# Processed batch 390/2606
# Processed batch 391/2606
# Processed batch 392/2606
# Processed batch 393/2606
# Processed batch 394/2606
# Processed batch 395/2606
# Processed batch 396/2606
# Processed batch 397/2606
# Processed batch 398/2606
# Processed batch 399/2606
# Processed batch 400/2606
# Processed batch 401/2606
# Processed batch 402/2606
# Processed batch 403/2606
# Processed batch 404/2606
# Processed batch 405/2606
# Processed batch 406/2606
# Processed batch 407/2606
# Processed batch 408/2606
# Processed batch 409/2606
# Processed batch 410/2606
# Processed batch 411/2606
# Processed batch 412/2606
# Processed batch 413/2606
# Processed batch 414/2606
# Processed batch 415/2606
# Processed batch 416/2606
# Processed batch 417/2606
# Processed batch 418/2606
# Processed batch 419/2606
# Processed batch 420/2606
# Processed batch 421/2606
# Processed batch 422/2606
# Processed batch 423/2606
# Processed batch 424/2606
# Processed batch 425/2606
# Processed batch 426/2606
# Processed batch 427/2606
# Processed batch 428/2606
# Processed batch 429/2606
# Processed batch 430/2606
# Processed batch 431/2606
# Processed batch 432/2606
# Processed batch 433/2606
# Processed batch 434/2606
# Processed batch 435/2606
# Processed batch 436/2606
# Processed batch 437/2606
# Processed batch 438/2606
# Processed batch 439/2606
# Processed batch 440/2606
# Processed batch 441/2606
# Processed batch 442/2606
# Processed batch 443/2606
# Processed batch 444/2606
# Processed batch 445/2606
# Processed batch 446/2606
# Processed batch 447/2606
# Processed batch 448/2606
# Processed batch 449/2606
# Processed batch 450/2606
# Processed batch 451/2606
# Processed batch 452/2606
# Processed batch 453/2606
# Processed batch 454/2606
# Processed batch 455/2606
# Processed batch 456/2606
# Processed batch 457/2606
# Processed batch 458/2606
# Processed batch 459/2606
# Processed batch 460/2606
# Processed batch 461/2606
# Processed batch 462/2606
# Processed batch 463/2606
# Processed batch 464/2606
# Processed batch 465/2606
# Processed batch 466/2606
# Processed batch 467/2606
# Processed batch 468/2606
# Processed batch 469/2606
# Processed batch 470/2606
# Processed batch 471/2606
# Processed batch 472/2606
# Processed batch 473/2606
# Processed batch 474/2606
# Processed batch 475/2606
# Processed batch 476/2606
# Processed batch 477/2606
# Processed batch 478/2606
# Processed batch 479/2606
# Processed batch 480/2606
# Processed batch 481/2606
# Processed batch 482/2606
# Processed batch 483/2606
# Processed batch 484/2606
# Processed batch 485/2606
# Processed batch 486/2606
# Processed batch 487/2606
# Processed batch 488/2606
# Processed batch 489/2606
# Processed batch 490/2606
# Processed batch 491/2606
# Processed batch 492/2606
# Processed batch 493/2606
# Processed batch 494/2606
# Processed batch 495/2606
# Processed batch 496/2606
# Processed batch 497/2606
# Processed batch 498/2606
# Processed batch 499/2606
# Processed batch 500/2606
# Processed batch 501/2606
# Processed batch 502/2606
# Processed batch 503/2606
# Processed batch 504/2606
# Processed batch 505/2606
# Processed batch 506/2606
# Processed batch 507/2606
# Processed batch 508/2606
# Processed batch 509/2606
# Processed batch 510/2606
# Processed batch 511/2606
# Processed batch 512/2606
# Processed batch 513/2606
# Processed batch 514/2606
# Processed batch 515/2606
# Processed batch 516/2606
# Processed batch 517/2606
# Processed batch 518/2606
# Processed batch 519/2606
# Processed batch 520/2606
# Processed batch 521/2606
# Processed batch 522/2606
# Processed batch 523/2606
# Processed batch 524/2606
# Processed batch 525/2606
# Processed batch 526/2606
# Processed batch 527/2606
# Processed batch 528/2606
# Processed batch 529/2606
# Processed batch 530/2606
# Processed batch 531/2606
# Processed batch 532/2606
# Processed batch 533/2606
# Processed batch 534/2606
# Processed batch 535/2606
# Processed batch 536/2606
# Processed batch 537/2606
# Processed batch 538/2606
# Processed batch 539/2606
# Processed batch 540/2606
# Processed batch 541/2606
# Processed batch 542/2606
# Processed batch 543/2606
# Processed batch 544/2606
# Processed batch 545/2606
# Processed batch 546/2606
# Processed batch 547/2606
# Processed batch 548/2606
# Processed batch 549/2606
# Processed batch 550/2606
# Processed batch 551/2606
# Processed batch 552/2606
# Processed batch 553/2606
# Processed batch 554/2606
# Processed batch 555/2606
# Processed batch 556/2606
# Processed batch 557/2606
# Processed batch 558/2606
# Processed batch 559/2606
# Processed batch 560/2606
# Processed batch 561/2606
# Processed batch 562/2606
# Processed batch 563/2606
# Processed batch 564/2606
# Processed batch 565/2606
# Processed batch 566/2606
# Processed batch 567/2606
# Processed batch 568/2606
# Processed batch 569/2606
# Processed batch 570/2606
# Processed batch 571/2606
# Processed batch 572/2606
# Processed batch 573/2606
# Processed batch 574/2606
# Processed batch 575/2606
# Processed batch 576/2606
# Processed batch 577/2606
# Processed batch 578/2606
# Processed batch 579/2606
# Processed batch 580/2606
# Processed batch 581/2606
# Processed batch 582/2606
# Processed batch 583/2606
# Processed batch 584/2606
# Processed batch 585/2606
# Processed batch 586/2606
# Processed batch 587/2606
# Processed batch 588/2606
# Processed batch 589/2606
# Processed batch 590/2606
# Processed batch 591/2606
# Processed batch 592/2606
# Processed batch 593/2606
# Processed batch 594/2606
# Processed batch 595/2606
# Processed batch 596/2606
# Processed batch 597/2606
# Processed batch 598/2606
# Processed batch 599/2606
# Processed batch 600/2606
# Processed batch 601/2606
# Processed batch 602/2606
# Processed batch 603/2606
# Processed batch 604/2606
# Processed batch 605/2606
# Processed batch 606/2606
# Processed batch 607/2606
# Processed batch 608/2606
# Processed batch 609/2606
# Processed batch 610/2606
# Processed batch 611/2606
# Processed batch 612/2606
# Processed batch 613/2606
# Processed batch 614/2606
# Processed batch 615/2606
# Processed batch 616/2606
# Processed batch 617/2606
# Processed batch 618/2606
# Processed batch 619/2606
# Processed batch 620/2606
# Processed batch 621/2606
# Processed batch 622/2606
# Processed batch 623/2606
# Processed batch 624/2606
# Processed batch 625/2606
# Processed batch 626/2606
# Processed batch 627/2606
# Processed batch 628/2606
# Processed batch 629/2606
# Processed batch 630/2606
# Processed batch 631/2606
# Processed batch 632/2606
# Processed batch 633/2606
# Processed batch 634/2606
# Processed batch 635/2606
# Processed batch 636/2606
# Processed batch 637/2606
# Processed batch 638/2606
# Processed batch 639/2606
# Processed batch 640/2606
# Processed batch 641/2606
# Processed batch 642/2606
# Processed batch 643/2606
# Processed batch 644/2606
# Processed batch 645/2606
# Processed batch 646/2606
# Processed batch 647/2606
# Processed batch 648/2606
# Processed batch 649/2606
# Processed batch 650/2606
# Processed batch 651/2606
# Processed batch 652/2606
# Processed batch 653/2606
# Processed batch 654/2606
# Processed batch 655/2606
# Processed batch 656/2606
# Processed batch 657/2606
# Processed batch 658/2606
# Processed batch 659/2606
# Processed batch 660/2606
# Processed batch 661/2606
# Processed batch 662/2606
# Processed batch 663/2606
# Processed batch 664/2606
# Processed batch 665/2606
# Processed batch 666/2606
# Processed batch 667/2606
# Processed batch 668/2606
# Processed batch 669/2606
# Processed batch 670/2606
# Processed batch 671/2606
# Processed batch 672/2606
# Processed batch 673/2606
# Processed batch 674/2606
# Processed batch 675/2606
# Processed batch 676/2606
# Processed batch 677/2606
# Processed batch 678/2606
# Processed batch 679/2606
# Processed batch 680/2606
# Processed batch 681/2606
# Processed batch 682/2606
# Processed batch 683/2606
# Processed batch 684/2606
# Processed batch 685/2606
# Processed batch 686/2606
# Processed batch 687/2606
# Processed batch 688/2606
# Processed batch 689/2606
# Processed batch 690/2606
# Processed batch 691/2606
# Processed batch 692/2606
# Processed batch 693/2606
# Processed batch 694/2606
# Processed batch 695/2606
# Processed batch 696/2606
# Processed batch 697/2606
# Processed batch 698/2606
# Processed batch 699/2606
# Processed batch 700/2606
# Processed batch 701/2606
# Processed batch 702/2606
# Processed batch 703/2606
# Processed batch 704/2606
# Processed batch 705/2606
# Processed batch 706/2606
# Processed batch 707/2606
# Processed batch 708/2606
# Processed batch 709/2606
# Processed batch 710/2606
# Processed batch 711/2606
# Processed batch 712/2606
# Processed batch 713/2606
# Processed batch 714/2606
# Processed batch 715/2606
# Processed batch 716/2606
# Processed batch 717/2606
# Processed batch 718/2606
# Processed batch 719/2606
# Processed batch 720/2606
# Processed batch 721/2606
# Processed batch 722/2606
# Processed batch 723/2606
# Processed batch 724/2606
# Processed batch 725/2606
# Processed batch 726/2606
# Processed batch 727/2606
# Processed batch 728/2606
# Processed batch 729/2606
# Processed batch 730/2606
# Processed batch 731/2606
# Processed batch 732/2606
# Processed batch 733/2606
# Processed batch 734/2606
# Processed batch 735/2606
# Processed batch 736/2606
# Processed batch 737/2606
# Processed batch 738/2606
# Processed batch 739/2606
# Processed batch 740/2606
# Processed batch 741/2606
# Processed batch 742/2606
# Processed batch 743/2606
# Processed batch 744/2606
# Processed batch 745/2606
# Processed batch 746/2606
# Processed batch 747/2606
# Processed batch 748/2606
# Processed batch 749/2606
# Processed batch 750/2606
# Processed batch 751/2606
# Processed batch 752/2606
# Processed batch 753/2606
# Processed batch 754/2606
# Processed batch 755/2606
# Processed batch 756/2606
# Processed batch 757/2606
# Processed batch 758/2606
# Processed batch 759/2606
# Processed batch 760/2606
# Processed batch 761/2606
# Processed batch 762/2606
# Processed batch 763/2606
# Processed batch 764/2606
# Processed batch 765/2606
# Processed batch 766/2606
# Processed batch 767/2606
# Processed batch 768/2606
# Processed batch 769/2606
# Processed batch 770/2606
# Processed batch 771/2606
# Processed batch 772/2606
# Processed batch 773/2606
# Processed batch 774/2606
# Processed batch 775/2606
# Processed batch 776/2606
# Processed batch 777/2606
# Processed batch 778/2606
# Processed batch 779/2606
# Processed batch 780/2606
# Processed batch 781/2606
# Processed batch 782/2606
# Processed batch 783/2606
# Processed batch 784/2606
# Processed batch 785/2606
# Processed batch 786/2606
# Processed batch 787/2606
# Processed batch 788/2606
# Processed batch 789/2606
# Processed batch 790/2606
# Processed batch 791/2606
# Processed batch 792/2606
# Processed batch 793/2606
# Processed batch 794/2606
# Processed batch 795/2606
# Processed batch 796/2606
# Processed batch 797/2606
# Processed batch 798/2606
# Processed batch 799/2606
# Processed batch 800/2606
# Processed batch 801/2606
# Processed batch 802/2606
# Processed batch 803/2606
# Processed batch 804/2606
# Processed batch 805/2606
# Processed batch 806/2606
# Processed batch 807/2606
# Processed batch 808/2606
# Processed batch 809/2606
# Processed batch 810/2606
# Processed batch 811/2606
# Processed batch 812/2606
# Processed batch 813/2606
# Processed batch 814/2606
# Processed batch 815/2606
# Processed batch 816/2606
# Processed batch 817/2606
# Processed batch 818/2606
# Processed batch 819/2606
# Processed batch 820/2606
# Processed batch 821/2606
# Processed batch 822/2606
# Processed batch 823/2606
# Processed batch 824/2606
# Processed batch 825/2606
# Processed batch 826/2606
# Processed batch 827/2606
# Processed batch 828/2606
# Processed batch 829/2606
# Processed batch 830/2606
# Processed batch 831/2606
# Processed batch 832/2606
# Processed batch 833/2606
# Processed batch 834/2606
# Processed batch 835/2606
# Processed batch 836/2606
# Processed batch 837/2606
# Processed batch 838/2606
# Processed batch 839/2606
# Processed batch 840/2606
# Processed batch 841/2606
# Processed batch 842/2606
# Processed batch 843/2606
# Processed batch 844/2606
# Processed batch 845/2606
# Processed batch 846/2606
# Processed batch 847/2606
# Processed batch 848/2606
# Processed batch 849/2606
# Processed batch 850/2606
# Processed batch 851/2606
# Processed batch 852/2606
# Processed batch 853/2606
# Processed batch 854/2606
# Processed batch 855/2606
# Processed batch 856/2606
# Processed batch 857/2606
# Processed batch 858/2606
# Processed batch 859/2606
# Processed batch 860/2606
# Processed batch 861/2606
# Processed batch 862/2606
# Processed batch 863/2606
# Processed batch 864/2606
# Processed batch 865/2606
# Processed batch 866/2606
# Processed batch 867/2606
# Processed batch 868/2606
# Processed batch 869/2606
# Processed batch 870/2606
# Processed batch 871/2606
# Processed batch 872/2606
# Processed batch 873/2606
# Processed batch 874/2606
# Processed batch 875/2606
# Processed batch 876/2606
# Processed batch 877/2606
# Processed batch 878/2606
# Processed batch 879/2606
# Processed batch 880/2606
# Processed batch 881/2606
# Processed batch 882/2606
# Processed batch 883/2606
# Processed batch 884/2606
# Processed batch 885/2606
# Processed batch 886/2606
# Processed batch 887/2606
# Processed batch 888/2606
# Processed batch 889/2606
# Processed batch 890/2606
# Processed batch 891/2606
# Processed batch 892/2606
# Processed batch 893/2606
# Processed batch 894/2606
# Processed batch 895/2606
# Processed batch 896/2606
# Processed batch 897/2606
# Processed batch 898/2606
# Processed batch 899/2606
# Processed batch 900/2606
# Processed batch 901/2606
# Processed batch 902/2606
# Processed batch 903/2606
# Processed batch 904/2606
# Processed batch 905/2606
# Processed batch 906/2606
# Processed batch 907/2606
# Processed batch 908/2606
# Processed batch 909/2606
# Processed batch 910/2606
# Processed batch 911/2606
# Processed batch 912/2606
# Processed batch 913/2606
# Processed batch 914/2606
# Processed batch 915/2606
# Processed batch 916/2606
# Processed batch 917/2606
# Processed batch 918/2606
# Processed batch 919/2606
# Processed batch 920/2606
# Processed batch 921/2606
# Processed batch 922/2606
# Processed batch 923/2606
# Processed batch 924/2606
# Processed batch 925/2606
# Processed batch 926/2606
# Processed batch 927/2606
# Processed batch 928/2606
# Processed batch 929/2606
# Processed batch 930/2606
# Processed batch 931/2606
# Processed batch 932/2606
# Processed batch 933/2606
# Processed batch 934/2606
# Processed batch 935/2606
# Processed batch 936/2606
# Processed batch 937/2606
# Processed batch 938/2606
# Processed batch 939/2606
# Processed batch 940/2606
# Processed batch 941/2606
# Processed batch 942/2606
# Processed batch 943/2606
# Processed batch 944/2606
# Processed batch 945/2606
# Processed batch 946/2606
# Processed batch 947/2606
# Processed batch 948/2606
# Processed batch 949/2606
# Processed batch 950/2606
# Processed batch 951/2606
# Processed batch 952/2606
# Processed batch 953/2606
# Processed batch 954/2606
# Processed batch 955/2606
# Processed batch 956/2606
# Processed batch 957/2606
# Processed batch 958/2606
# Processed batch 959/2606
# Processed batch 960/2606
# Processed batch 961/2606
# Processed batch 962/2606
# Processed batch 963/2606
# Processed batch 964/2606
# Processed batch 965/2606
# Processed batch 966/2606
# Processed batch 967/2606
# Processed batch 968/2606
# Processed batch 969/2606
# Processed batch 970/2606
# Processed batch 971/2606
# Processed batch 972/2606
# Processed batch 973/2606
# Processed batch 974/2606
# Processed batch 975/2606
# Processed batch 976/2606
# Processed batch 977/2606
# Processed batch 978/2606
# Processed batch 979/2606
# Processed batch 980/2606
# Processed batch 981/2606
# Processed batch 982/2606
# Processed batch 983/2606
# Processed batch 984/2606
# Processed batch 985/2606
# Processed batch 986/2606
# Processed batch 987/2606
# Processed batch 988/2606
# Processed batch 989/2606
# Processed batch 990/2606
# Processed batch 991/2606
# Processed batch 992/2606
# Processed batch 993/2606
# Processed batch 994/2606
# Processed batch 995/2606
# Processed batch 996/2606
# Processed batch 997/2606
# Processed batch 998/2606
# Processed batch 999/2606
# Processed batch 1000/2606
# Processed batch 1001/2606
# Processed batch 1002/2606
# Processed batch 1003/2606
# Processed batch 1004/2606
# Processed batch 1005/2606
# Processed batch 1006/2606
# Processed batch 1007/2606
# Processed batch 1008/2606
# Processed batch 1009/2606
# Processed batch 1010/2606
# Processed batch 1011/2606
# Processed batch 1012/2606
# Processed batch 1013/2606
# Processed batch 1014/2606
# Processed batch 1015/2606
# Processed batch 1016/2606
# Processed batch 1017/2606
# Processed batch 1018/2606
# Processed batch 1019/2606
# Processed batch 1020/2606
# Processed batch 1021/2606
# Processed batch 1022/2606
# Processed batch 1023/2606
# Processed batch 1024/2606
# Processed batch 1025/2606
# Processed batch 1026/2606
# Processed batch 1027/2606
# Processed batch 1028/2606
# Processed batch 1029/2606
# Processed batch 1030/2606
# Processed batch 1031/2606
# Processed batch 1032/2606
# Processed batch 1033/2606
# Processed batch 1034/2606
# Processed batch 1035/2606
# Processed batch 1036/2606
# Processed batch 1037/2606
# Processed batch 1038/2606
# Processed batch 1039/2606
# Processed batch 1040/2606
# Processed batch 1041/2606
# Processed batch 1042/2606
# Processed batch 1043/2606
# Processed batch 1044/2606
# Processed batch 1045/2606
# Processed batch 1046/2606
# Processed batch 1047/2606
# Processed batch 1048/2606
# Processed batch 1049/2606
# Processed batch 1050/2606
# Processed batch 1051/2606
# Processed batch 1052/2606
# Processed batch 1053/2606
# Processed batch 1054/2606
# Processed batch 1055/2606
# Processed batch 1056/2606
# Processed batch 1057/2606
# Processed batch 1058/2606
# Processed batch 1059/2606
# Processed batch 1060/2606
# Processed batch 1061/2606
# Processed batch 1062/2606
# Processed batch 1063/2606
# Processed batch 1064/2606
# Processed batch 1065/2606
# Processed batch 1066/2606
# Processed batch 1067/2606
# Processed batch 1068/2606
# Processed batch 1069/2606
# Processed batch 1070/2606
# Processed batch 1071/2606
# Processed batch 1072/2606
# Processed batch 1073/2606
# Processed batch 1074/2606
# Processed batch 1075/2606
# Processed batch 1076/2606
# Processed batch 1077/2606
# Processed batch 1078/2606
# Processed batch 1079/2606
# Processed batch 1080/2606
# Processed batch 1081/2606
# Processed batch 1082/2606
# Processed batch 1083/2606
# Processed batch 1084/2606
# Processed batch 1085/2606
# Processed batch 1086/2606
# Processed batch 1087/2606
# Processed batch 1088/2606
# Processed batch 1089/2606
# Processed batch 1090/2606
# Processed batch 1091/2606
# Processed batch 1092/2606
# Processed batch 1093/2606
# Processed batch 1094/2606
# Processed batch 1095/2606
# Processed batch 1096/2606
# Processed batch 1097/2606
# Processed batch 1098/2606
# Processed batch 1099/2606
# Processed batch 1100/2606
# Processed batch 1101/2606
# Processed batch 1102/2606
# Processed batch 1103/2606
# Processed batch 1104/2606
# Processed batch 1105/2606
# Processed batch 1106/2606
# Processed batch 1107/2606
# Processed batch 1108/2606
# Processed batch 1109/2606
# Processed batch 1110/2606
# Processed batch 1111/2606
# Processed batch 1112/2606
# Processed batch 1113/2606
# Processed batch 1114/2606
# Processed batch 1115/2606
# Processed batch 1116/2606
# Processed batch 1117/2606
# Processed batch 1118/2606
# Processed batch 1119/2606
# Processed batch 1120/2606
# Processed batch 1121/2606
# Processed batch 1122/2606
# Processed batch 1123/2606
# Processed batch 1124/2606
# Processed batch 1125/2606
# Processed batch 1126/2606
# Processed batch 1127/2606
# Processed batch 1128/2606
# Processed batch 1129/2606
# Processed batch 1130/2606
# Processed batch 1131/2606
# Processed batch 1132/2606
# Processed batch 1133/2606
# Processed batch 1134/2606
# Processed batch 1135/2606
# Processed batch 1136/2606
# Processed batch 1137/2606
# Processed batch 1138/2606
# Processed batch 1139/2606
# Processed batch 1140/2606
# Processed batch 1141/2606
# Processed batch 1142/2606
# Processed batch 1143/2606
# Processed batch 1144/2606
# Processed batch 1145/2606
# Processed batch 1146/2606
# Processed batch 1147/2606
# Processed batch 1148/2606
# Processed batch 1149/2606
# Processed batch 1150/2606
# Processed batch 1151/2606
# Processed batch 1152/2606
# Processed batch 1153/2606
# Processed batch 1154/2606
# Processed batch 1155/2606
# Processed batch 1156/2606
# Processed batch 1157/2606
# Processed batch 1158/2606
# Processed batch 1159/2606
# Processed batch 1160/2606
# Processed batch 1161/2606
# Processed batch 1162/2606
# Processed batch 1163/2606
# Processed batch 1164/2606
# Processed batch 1165/2606
# Processed batch 1166/2606
# Processed batch 1167/2606
# Processed batch 1168/2606
# Processed batch 1169/2606
# Processed batch 1170/2606
# Processed batch 1171/2606
# Processed batch 1172/2606
# Processed batch 1173/2606
# Processed batch 1174/2606
# Processed batch 1175/2606
# Processed batch 1176/2606
# Processed batch 1177/2606
# Processed batch 1178/2606
# Processed batch 1179/2606
# Processed batch 1180/2606
# Processed batch 1181/2606
# Processed batch 1182/2606
# Processed batch 1183/2606
# Processed batch 1184/2606
# Processed batch 1185/2606
# Processed batch 1186/2606
# Processed batch 1187/2606
# Processed batch 1188/2606
# Processed batch 1189/2606
# Processed batch 1190/2606
# Processed batch 1191/2606
# Processed batch 1192/2606
# Processed batch 1193/2606
# Processed batch 1194/2606
# Processed batch 1195/2606
# Processed batch 1196/2606
# Processed batch 1197/2606
# Processed batch 1198/2606
# Processed batch 1199/2606
# Processed batch 1200/2606
# Processed batch 1201/2606
# Processed batch 1202/2606
# Processed batch 1203/2606
# Processed batch 1204/2606
# Processed batch 1205/2606
# Processed batch 1206/2606
# Processed batch 1207/2606
# Processed batch 1208/2606
# Processed batch 1209/2606
# Processed batch 1210/2606
# Processed batch 1211/2606
# Processed batch 1212/2606
# Processed batch 1213/2606
# Processed batch 1214/2606
# Processed batch 1215/2606
# Processed batch 1216/2606
# Processed batch 1217/2606
# Processed batch 1218/2606
# Processed batch 1219/2606
# Processed batch 1220/2606
# Processed batch 1221/2606
# Processed batch 1222/2606
# Processed batch 1223/2606
# Processed batch 1224/2606
# Processed batch 1225/2606
# Processed batch 1226/2606
# Processed batch 1227/2606
# Processed batch 1228/2606
# Processed batch 1229/2606
# Processed batch 1230/2606
# Processed batch 1231/2606
# Processed batch 1232/2606
# Processed batch 1233/2606
# Processed batch 1234/2606
# Processed batch 1235/2606
# Processed batch 1236/2606
# Processed batch 1237/2606
# Processed batch 1238/2606
# Processed batch 1239/2606
# Processed batch 1240/2606
# Processed batch 1241/2606
# Processed batch 1242/2606
# Processed batch 1243/2606
# Processed batch 1244/2606
# Processed batch 1245/2606
# Processed batch 1246/2606
# Processed batch 1247/2606
# Processed batch 1248/2606
# Processed batch 1249/2606
# Processed batch 1250/2606
# Processed batch 1251/2606
# Processed batch 1252/2606
# Processed batch 1253/2606
# Processed batch 1254/2606
# Processed batch 1255/2606
# Processed batch 1256/2606
# Processed batch 1257/2606
# Processed batch 1258/2606
# Processed batch 1259/2606
# Processed batch 1260/2606
# Processed batch 1261/2606
# Processed batch 1262/2606
# Processed batch 1263/2606
# Processed batch 1264/2606
# Processed batch 1265/2606
# Processed batch 1266/2606
# Processed batch 1267/2606
# Processed batch 1268/2606
# Processed batch 1269/2606
# Processed batch 1270/2606
# Processed batch 1271/2606
# Processed batch 1272/2606
# Processed batch 1273/2606
# Processed batch 1274/2606
# Processed batch 1275/2606
# Processed batch 1276/2606
# Processed batch 1277/2606
# Processed batch 1278/2606
# Processed batch 1279/2606
# Processed batch 1280/2606
# Processed batch 1281/2606
# Processed batch 1282/2606
# Processed batch 1283/2606
# Processed batch 1284/2606
# Processed batch 1285/2606
# Processed batch 1286/2606
# Processed batch 1287/2606
# Processed batch 1288/2606
# Processed batch 1289/2606
# Processed batch 1290/2606
# Processed batch 1291/2606
# Processed batch 1292/2606
# Processed batch 1293/2606
# Processed batch 1294/2606
# Processed batch 1295/2606
# Processed batch 1296/2606
# Processed batch 1297/2606
# Processed batch 1298/2606
# Processed batch 1299/2606
# Processed batch 1300/2606
# Processed batch 1301/2606
# Processed batch 1302/2606
# Processed batch 1303/2606
# Processed batch 1304/2606
# Processed batch 1305/2606
# Processed batch 1306/2606
# Processed batch 1307/2606
# Processed batch 1308/2606
# Processed batch 1309/2606
# Processed batch 1310/2606
# Processed batch 1311/2606
# Processed batch 1312/2606
# Processed batch 1313/2606
# Processed batch 1314/2606
# Processed batch 1315/2606
# Processed batch 1316/2606
# Processed batch 1317/2606
# Processed batch 1318/2606
# Processed batch 1319/2606
# Processed batch 1320/2606
# Processed batch 1321/2606
# Processed batch 1322/2606
# Processed batch 1323/2606
# Processed batch 1324/2606
# Processed batch 1325/2606
# Processed batch 1326/2606
# Processed batch 1327/2606
# Processed batch 1328/2606
# Processed batch 1329/2606
# Processed batch 1330/2606
# Processed batch 1331/2606
# Processed batch 1332/2606
# Processed batch 1333/2606
# Processed batch 1334/2606
# Processed batch 1335/2606
# Processed batch 1336/2606
# Processed batch 1337/2606
# Processed batch 1338/2606
# Processed batch 1339/2606
# Processed batch 1340/2606
# Processed batch 1341/2606
# Processed batch 1342/2606
# Processed batch 1343/2606
# Processed batch 1344/2606
# Processed batch 1345/2606
# Processed batch 1346/2606
# Processed batch 1347/2606
# Processed batch 1348/2606
# Processed batch 1349/2606
# Processed batch 1350/2606
# Processed batch 1351/2606
# Processed batch 1352/2606
# Processed batch 1353/2606
# Processed batch 1354/2606
# Processed batch 1355/2606
# Processed batch 1356/2606
# Processed batch 1357/2606
# Processed batch 1358/2606
# Processed batch 1359/2606
# Processed batch 1360/2606
# Processed batch 1361/2606
# Processed batch 1362/2606
# Processed batch 1363/2606
# Processed batch 1364/2606
# Processed batch 1365/2606
# Processed batch 1366/2606
# Processed batch 1367/2606
# Processed batch 1368/2606
# Processed batch 1369/2606
# Processed batch 1370/2606
# Processed batch 1371/2606
# Processed batch 1372/2606
# Processed batch 1373/2606
# Processed batch 1374/2606
# Processed batch 1375/2606
# Processed batch 1376/2606
# Processed batch 1377/2606
# Processed batch 1378/2606
# Processed batch 1379/2606
# Processed batch 1380/2606
# Processed batch 1381/2606
# Processed batch 1382/2606
# Processed batch 1383/2606
# Processed batch 1384/2606
# Processed batch 1385/2606
# Processed batch 1386/2606
# Processed batch 1387/2606
# Processed batch 1388/2606
# Processed batch 1389/2606
# Processed batch 1390/2606
# Processed batch 1391/2606
# Processed batch 1392/2606
# Processed batch 1393/2606
# Processed batch 1394/2606
# Processed batch 1395/2606
# Processed batch 1396/2606
# Processed batch 1397/2606
# Processed batch 1398/2606
# Processed batch 1399/2606
# Processed batch 1400/2606
# Processed batch 1401/2606
# Processed batch 1402/2606
# Processed batch 1403/2606
# Processed batch 1404/2606
# Processed batch 1405/2606
# Processed batch 1406/2606
# Processed batch 1407/2606
# Processed batch 1408/2606
# Processed batch 1409/2606
# Processed batch 1410/2606
# Processed batch 1411/2606
# Processed batch 1412/2606
# Processed batch 1413/2606
# Processed batch 1414/2606
# Processed batch 1415/2606
# Processed batch 1416/2606
# Processed batch 1417/2606
# Processed batch 1418/2606
# Processed batch 1419/2606
# Processed batch 1420/2606
# Processed batch 1421/2606
# Processed batch 1422/2606
# Processed batch 1423/2606
# Processed batch 1424/2606
# Processed batch 1425/2606
# Processed batch 1426/2606
# Processed batch 1427/2606
# Processed batch 1428/2606
# Processed batch 1429/2606
# Processed batch 1430/2606
# Processed batch 1431/2606
# Processed batch 1432/2606
# Processed batch 1433/2606
# Processed batch 1434/2606
# Processed batch 1435/2606
# Processed batch 1436/2606
# Processed batch 1437/2606
# Processed batch 1438/2606
# Processed batch 1439/2606
# Processed batch 1440/2606
# Processed batch 1441/2606
# Processed batch 1442/2606
# Processed batch 1443/2606
# Processed batch 1444/2606
# Processed batch 1445/2606
# Processed batch 1446/2606
# Processed batch 1447/2606
# Processed batch 1448/2606
# Processed batch 1449/2606
# Processed batch 1450/2606
# Processed batch 1451/2606
# Processed batch 1452/2606
# Processed batch 1453/2606
# Processed batch 1454/2606
# Processed batch 1455/2606
# Processed batch 1456/2606
# Processed batch 1457/2606
# Processed batch 1458/2606
# Processed batch 1459/2606
# Processed batch 1460/2606
# Processed batch 1461/2606
# Processed batch 1462/2606
# Processed batch 1463/2606
# Processed batch 1464/2606
# Processed batch 1465/2606
# Processed batch 1466/2606
# Processed batch 1467/2606
# Processed batch 1468/2606
# Processed batch 1469/2606
# Processed batch 1470/2606
# Processed batch 1471/2606
# Processed batch 1472/2606
# Processed batch 1473/2606
# Processed batch 1474/2606
# Processed batch 1475/2606
# Processed batch 1476/2606
# Processed batch 1477/2606
# Processed batch 1478/2606
# Processed batch 1479/2606
# Processed batch 1480/2606
# Processed batch 1481/2606
# Processed batch 1482/2606
# Processed batch 1483/2606
# Processed batch 1484/2606
# Processed batch 1485/2606
# Processed batch 1486/2606
# Processed batch 1487/2606
# Processed batch 1488/2606
# Processed batch 1489/2606
# Processed batch 1490/2606
# Processed batch 1491/2606
# Processed batch 1492/2606
# Processed batch 1493/2606
# Processed batch 1494/2606
# Processed batch 1495/2606
# Processed batch 1496/2606
# Processed batch 1497/2606
# Processed batch 1498/2606
# Processed batch 1499/2606
# Processed batch 1500/2606
# Processed batch 1501/2606
# Processed batch 1502/2606
# Processed batch 1503/2606
# Processed batch 1504/2606
# Processed batch 1505/2606
# Processed batch 1506/2606
# Processed batch 1507/2606
# Processed batch 1508/2606
# Processed batch 1509/2606
# Processed batch 1510/2606
# Processed batch 1511/2606
# Processed batch 1512/2606
# Processed batch 1513/2606
# Processed batch 1514/2606
# Processed batch 1515/2606
# Processed batch 1516/2606
# Processed batch 1517/2606
# Processed batch 1518/2606
# Processed batch 1519/2606
# Processed batch 1520/2606
# Processed batch 1521/2606
# Processed batch 1522/2606
# Processed batch 1523/2606
# Processed batch 1524/2606
# Processed batch 1525/2606
# Processed batch 1526/2606
# Processed batch 1527/2606
# Processed batch 1528/2606
# Processed batch 1529/2606
# Processed batch 1530/2606
# Processed batch 1531/2606
# Processed batch 1532/2606
# Processed batch 1533/2606
# Processed batch 1534/2606
# Processed batch 1535/2606
# Processed batch 1536/2606
# Processed batch 1537/2606
# Processed batch 1538/2606
# Processed batch 1539/2606
# Processed batch 1540/2606
# Processed batch 1541/2606
# Processed batch 1542/2606
# Processed batch 1543/2606
# Processed batch 1544/2606
# Processed batch 1545/2606
# Processed batch 1546/2606
# Processed batch 1547/2606
# Processed batch 1548/2606
# Processed batch 1549/2606
# Processed batch 1550/2606
# Processed batch 1551/2606
# Processed batch 1552/2606
# Processed batch 1553/2606
# Processed batch 1554/2606
# Processed batch 1555/2606
# Processed batch 1556/2606
# Processed batch 1557/2606
# Processed batch 1558/2606
# Processed batch 1559/2606
# Processed batch 1560/2606
# Processed batch 1561/2606
# Processed batch 1562/2606
# Processed batch 1563/2606
# Processed batch 1564/2606
# Processed batch 1565/2606
# Processed batch 1566/2606
# Processed batch 1567/2606
# Processed batch 1568/2606
# Processed batch 1569/2606
# Processed batch 1570/2606
# Processed batch 1571/2606
# Processed batch 1572/2606
# Processed batch 1573/2606
# Processed batch 1574/2606
# Processed batch 1575/2606
# Processed batch 1576/2606
# Processed batch 1577/2606
# Processed batch 1578/2606
# Processed batch 1579/2606
# Processed batch 1580/2606
# Processed batch 1581/2606
# Processed batch 1582/2606
# Processed batch 1583/2606
# Processed batch 1584/2606
# Processed batch 1585/2606
# Processed batch 1586/2606
# Processed batch 1587/2606
# Processed batch 1588/2606
# Processed batch 1589/2606
# Processed batch 1590/2606
# Processed batch 1591/2606
# Processed batch 1592/2606
# Processed batch 1593/2606
# Processed batch 1594/2606
# Processed batch 1595/2606
# Processed batch 1596/2606
# Processed batch 1597/2606
# Processed batch 1598/2606
# Processed batch 1599/2606
# Processed batch 1600/2606
# Processed batch 1601/2606
# Processed batch 1602/2606
# Processed batch 1603/2606
# Processed batch 1604/2606
# Processed batch 1605/2606
# Processed batch 1606/2606
# Processed batch 1607/2606
# Processed batch 1608/2606
# Processed batch 1609/2606
# Processed batch 1610/2606
# Processed batch 1611/2606
# Processed batch 1612/2606
# Processed batch 1613/2606
# Processed batch 1614/2606
# Processed batch 1615/2606
# Processed batch 1616/2606
# Processed batch 1617/2606
# Processed batch 1618/2606
# Processed batch 1619/2606
# Processed batch 1620/2606
# Processed batch 1621/2606
# Processed batch 1622/2606
# Processed batch 1623/2606
# Processed batch 1624/2606
# Processed batch 1625/2606
# Processed batch 1626/2606
# Processed batch 1627/2606
# Processed batch 1628/2606
# Processed batch 1629/2606
# Processed batch 1630/2606
# Processed batch 1631/2606
# Processed batch 1632/2606
# Processed batch 1633/2606
# Processed batch 1634/2606
# Processed batch 1635/2606
# Processed batch 1636/2606
# Processed batch 1637/2606
# Processed batch 1638/2606
# Processed batch 1639/2606
# Processed batch 1640/2606
# Processed batch 1641/2606
# Processed batch 1642/2606
# Processed batch 1643/2606
# Processed batch 1644/2606
# Processed batch 1645/2606
# Processed batch 1646/2606
# Processed batch 1647/2606
# Processed batch 1648/2606
# Processed batch 1649/2606
# Processed batch 1650/2606
# Processed batch 1651/2606
# Processed batch 1652/2606
# Processed batch 1653/2606
# Processed batch 1654/2606
# Processed batch 1655/2606
# Processed batch 1656/2606
# Processed batch 1657/2606
# Processed batch 1658/2606
# Processed batch 1659/2606
# Processed batch 1660/2606
# Processed batch 1661/2606
# Processed batch 1662/2606
# Processed batch 1663/2606
# Processed batch 1664/2606
# Processed batch 1665/2606
# Processed batch 1666/2606
# Processed batch 1667/2606
# Processed batch 1668/2606
# Processed batch 1669/2606
# Processed batch 1670/2606
# Processed batch 1671/2606
# Processed batch 1672/2606
# Processed batch 1673/2606
# Processed batch 1674/2606
# Processed batch 1675/2606
# Processed batch 1676/2606
# Processed batch 1677/2606
# Processed batch 1678/2606
# Processed batch 1679/2606
# Processed batch 1680/2606
# Processed batch 1681/2606
# Processed batch 1682/2606
# Processed batch 1683/2606
# Processed batch 1684/2606
# Processed batch 1685/2606
# Processed batch 1686/2606
# Processed batch 1687/2606
# Processed batch 1688/2606
# Processed batch 1689/2606
# Processed batch 1690/2606
# Processed batch 1691/2606
# Processed batch 1692/2606
# Processed batch 1693/2606
# Processed batch 1694/2606
# Processed batch 1695/2606
# Processed batch 1696/2606
# Processed batch 1697/2606
# Processed batch 1698/2606
# Processed batch 1699/2606
# Processed batch 1700/2606
# Processed batch 1701/2606
# Processed batch 1702/2606
# Processed batch 1703/2606
# Processed batch 1704/2606
# Processed batch 1705/2606
# Processed batch 1706/2606
# Processed batch 1707/2606
# Processed batch 1708/2606
# Processed batch 1709/2606
# Processed batch 1710/2606
# Processed batch 1711/2606
# Processed batch 1712/2606
# Processed batch 1713/2606
# Processed batch 1714/2606
# Processed batch 1715/2606
# Processed batch 1716/2606
# Processed batch 1717/2606
# Processed batch 1718/2606
# Processed batch 1719/2606
# Processed batch 1720/2606
# Processed batch 1721/2606
# Processed batch 1722/2606
# Processed batch 1723/2606
# Processed batch 1724/2606
# Processed batch 1725/2606
# Processed batch 1726/2606
# Processed batch 1727/2606
# Processed batch 1728/2606
# Processed batch 1729/2606
# Processed batch 1730/2606
# Processed batch 1731/2606
# Processed batch 1732/2606
# Processed batch 1733/2606
# Processed batch 1734/2606
# Processed batch 1735/2606
# Processed batch 1736/2606
# Processed batch 1737/2606
# Processed batch 1738/2606
# Processed batch 1739/2606
# Processed batch 1740/2606
# Processed batch 1741/2606
# Processed batch 1742/2606
# Processed batch 1743/2606
# Processed batch 1744/2606
# Processed batch 1745/2606
# Processed batch 1746/2606
# Processed batch 1747/2606
# Processed batch 1748/2606
# Processed batch 1749/2606
# Processed batch 1750/2606
# Processed batch 1751/2606
# Processed batch 1752/2606
# Processed batch 1753/2606
# Processed batch 1754/2606
# Processed batch 1755/2606
# Processed batch 1756/2606
# Processed batch 1757/2606
# Processed batch 1758/2606
# Processed batch 1759/2606
# Processed batch 1760/2606
# Processed batch 1761/2606
# Processed batch 1762/2606
# Processed batch 1763/2606
# Processed batch 1764/2606
# Processed batch 1765/2606
# Processed batch 1766/2606
# Processed batch 1767/2606
# Processed batch 1768/2606
# Processed batch 1769/2606
# Processed batch 1770/2606
# Processed batch 1771/2606
# Processed batch 1772/2606
# Processed batch 1773/2606
# Processed batch 1774/2606
# Processed batch 1775/2606
# Processed batch 1776/2606
# Processed batch 1777/2606
# Processed batch 1778/2606
# Processed batch 1779/2606
# Processed batch 1780/2606
# Processed batch 1781/2606
# Processed batch 1782/2606
# Processed batch 1783/2606
# Processed batch 1784/2606
# Processed batch 1785/2606
# Processed batch 1786/2606
# Processed batch 1787/2606
# Processed batch 1788/2606
# Processed batch 1789/2606
# Processed batch 1790/2606
# Processed batch 1791/2606
# Processed batch 1792/2606
# Processed batch 1793/2606
# Processed batch 1794/2606
# Processed batch 1795/2606
# Processed batch 1796/2606
# Processed batch 1797/2606
# Processed batch 1798/2606
# Processed batch 1799/2606
# Processed batch 1800/2606
# Processed batch 1801/2606
# Processed batch 1802/2606
# Processed batch 1803/2606
# Processed batch 1804/2606
# Processed batch 1805/2606
# Processed batch 1806/2606
# Processed batch 1807/2606
# Processed batch 1808/2606
# Processed batch 1809/2606
# Processed batch 1810/2606
# Processed batch 1811/2606
# Processed batch 1812/2606
# Processed batch 1813/2606
# Processed batch 1814/2606
# Processed batch 1815/2606
# Processed batch 1816/2606
# Processed batch 1817/2606
# Processed batch 1818/2606
# Processed batch 1819/2606
# Processed batch 1820/2606
# Processed batch 1821/2606
# Processed batch 1822/2606
# Processed batch 1823/2606
# Processed batch 1824/2606
# Processed batch 1825/2606
# Processed batch 1826/2606
# Processed batch 1827/2606
# Processed batch 1828/2606
# Processed batch 1829/2606
# Processed batch 1830/2606
# Processed batch 1831/2606
# Processed batch 1832/2606
# Processed batch 1833/2606
# Processed batch 1834/2606
# Processed batch 1835/2606
# Processed batch 1836/2606
# Processed batch 1837/2606
# Processed batch 1838/2606
# Processed batch 1839/2606
# Processed batch 1840/2606
# Processed batch 1841/2606
# Processed batch 1842/2606
# Processed batch 1843/2606
# Processed batch 1844/2606
# Processed batch 1845/2606
# Processed batch 1846/2606
# Processed batch 1847/2606
# Processed batch 1848/2606
# Processed batch 1849/2606
# Processed batch 1850/2606
# Processed batch 1851/2606
# Processed batch 1852/2606
# Processed batch 1853/2606
# Processed batch 1854/2606
# Processed batch 1855/2606
# Processed batch 1856/2606
# Processed batch 1857/2606
# Processed batch 1858/2606
# Processed batch 1859/2606
# Processed batch 1860/2606
# Processed batch 1861/2606
# Processed batch 1862/2606
# Processed batch 1863/2606
# Processed batch 1864/2606
# Processed batch 1865/2606
# Processed batch 1866/2606
# Processed batch 1867/2606
# Processed batch 1868/2606
# Processed batch 1869/2606
# Processed batch 1870/2606
# Processed batch 1871/2606
# Processed batch 1872/2606
# Processed batch 1873/2606
# Processed batch 1874/2606
# Processed batch 1875/2606
# Processed batch 1876/2606
# Processed batch 1877/2606
# Processed batch 1878/2606
# Processed batch 1879/2606
# Processed batch 1880/2606
# Processed batch 1881/2606
# Processed batch 1882/2606
# Processed batch 1883/2606
# Processed batch 1884/2606
# Processed batch 1885/2606
# ...
# Processed batch 2008/2606
# Processed batch 2009/2606
# Processed batch 2010/2606
# Processed batch 2011/2606
# Processed batch 2012/2606
# Processed batch 2013/2606
# Processed batch 2014/2606
# Processed batch 2015/2606
# Processed batch 2016/2606
# Processed batch 2017/2606
# Processed batch 2018/2606
# Processed batch 2019/2606
# Processed batch 2020/2606
# Processed batch 2021/2606
# Processed batch 2022/2606
# Processed batch 2023/2606
# Processed batch 2024/2606
# Processed batch 2025/2606
# Processed batch 2026/2606
# Processed batch 2027/2606
# Processed batch 2028/2606
# Processed batch 2029/2606
# Processed batch 2030/2606
# Processed batch 2031/2606
# Processed batch 2032/2606
# Processed batch 2033/2606
# Processed batch 2034/2606
# Processed batch 2035/2606
# Processed batch 2036/2606
# Processed batch 2037/2606
# Processed batch 2038/2606
# Processed batch 2039/2606
# Processed batch 2040/2606
# Processed batch 2041/2606
# Processed batch 2042/2606
# Processed batch 2043/2606
# Processed batch 2044/2606
# Processed batch 2045/2606
# Processed batch 2046/2606
# Processed batch 2047/2606
# Processed batch 2048/2606
# Processed batch 2049/2606
# Processed batch 2050/2606
# Processed batch 2051/2606
# Processed batch 2052/2606
# Processed batch 2053/2606
# Processed batch 2054/2606
# Processed batch 2055/2606
# Processed batch 2056/2606
# Processed batch 2057/2606
# Processed batch 2058/2606
# Processed batch 2059/2606
# Processed batch 2060/2606
# Processed batch 2061/2606
# Processed batch 2062/2606
# Processed batch 2063/2606
# Processed batch 2064/2606
# Processed batch 2065/2606
# Processed batch 2066/2606
# Processed batch 2067/2606
# Processed batch 2068/2606
# Processed batch 2069/2606
# Processed batch 2070/2606
# Processed batch 2071/2606
# Processed batch 2072/2606
# Processed batch 2073/2606
# Processed batch 2074/2606
# Processed batch 2075/2606
# Processed batch 2076/2606
# Processed batch 2077/2606
# Processed batch 2078/2606
# Processed batch 2079/2606
# Processed batch 2080/2606
# Processed batch 2081/2606
# Processed batch 2082/2606
# Processed batch 2083/2606
# Processed batch 2084/2606
# Processed batch 2085/2606
# Processed batch 2086/2606
# Processed batch 2087/2606
# Processed batch 2088/2606
# Processed batch 2089/2606
# Processed batch 2090/2606
# Processed batch 2091/2606
# Processed batch 2092/2606
# Processed batch 2093/2606
# Processed batch 2094/2606
# Processed batch 2095/2606
# Processed batch 2096/2606
# Processed batch 2097/2606
# Processed batch 2098/2606
# Processed batch 2099/2606
# Processed batch 2100/2606
# Processed batch 2101/2606
# Processed batch 2102/2606
# Processed batch 2103/2606
# Processed batch 2104/2606
# Processed batch 2105/2606
# Processed batch 2106/2606
# Processed batch 2107/2606
# Processed batch 2108/2606
# Processed batch 2109/2606
# Processed batch 2110/2606
# Processed batch 2111/2606
# Processed batch 2112/2606
# Processed batch 2113/2606
# Processed batch 2114/2606
# Processed batch 2115/2606
# Processed batch 2116/2606
# Processed batch 2117/2606
# Processed batch 2118/2606
# Processed batch 2119/2606
# Processed batch 2120/2606
# Processed batch 2121/2606
# Processed batch 2122/2606
# Processed batch 2123/2606
# Processed batch 2124/2606
# Processed batch 2125/2606
# Processed batch 2126/2606
# Processed batch 2127/2606
# Processed batch 2128/2606
# Processed batch 2129/2606
# Processed batch 2130/2606
# Processed batch 2131/2606
# Processed batch 2132/2606
# Processed batch 2133/2606
# Processed batch 2134/2606
# Processed batch 2135/2606
# Processed batch 2136/2606
# Processed batch 2137/2606
# Processed batch 2138/2606
# Processed batch 2139/2606
# Processed batch 2140/2606
# Processed batch 2141/2606
# Processed batch 2142/2606
# Processed batch 2143/2606
# Processed batch 2144/2606
# Processed batch 2145/2606
# Processed batch 2146/2606
# Processed batch 2147/2606
# Processed batch 2148/2606
# Processed batch 2149/2606
# Processed batch 2150/2606
# Processed batch 2151/2606
# Processed batch 2152/2606
# Processed batch 2153/2606
# Processed batch 2154/2606
# Processed batch 2155/2606
# Processed batch 2156/2606
# Processed batch 2157/2606
# Processed batch 2158/2606
# Processed batch 2159/2606
# Processed batch 2160/2606
# Processed batch 2161/2606
# Processed batch 2162/2606
# Processed batch 2163/2606
# Processed batch 2164/2606
# Processed batch 2165/2606
# Processed batch 2166/2606
# Processed batch 2167/2606
# Processed batch 2168/2606
# Processed batch 2169/2606
# Processed batch 2170/2606
# Processed batch 2171/2606
# Processed batch 2172/2606
# Processed batch 2173/2606
# Processed batch 2174/2606
# Processed batch 2175/2606
# Processed batch 2176/2606
# Processed batch 2177/2606
# Processed batch 2178/2606
# Processed batch 2179/2606
# Processed batch 2180/2606
# Processed batch 2181/2606
# Processed batch 2182/2606
# Processed batch 2183/2606
# Processed batch 2184/2606
# Processed batch 2185/2606
# Processed batch 2186/2606
# Processed batch 2187/2606
# Processed batch 2188/2606
# Processed batch 2189/2606
# Processed batch 2190/2606
# Processed batch 2191/2606
# Processed batch 2192/2606
# Processed batch 2193/2606
# Processed batch 2194/2606
# Processed batch 2195/2606
# Processed batch 2196/2606
# Processed batch 2197/2606
# Processed batch 2198/2606
# Processed batch 2199/2606
# Processed batch 2200/2606
# Processed batch 2201/2606
# Processed batch 2202/2606
# Processed batch 2203/2606
# Processed batch 2204/2606
# Processed batch 2205/2606
# Processed batch 2206/2606
# Processed batch 2207/2606
# Processed batch 2208/2606
# Processed batch 2209/2606
# Processed batch 2210/2606
# Processed batch 2211/2606
# Processed batch 2212/2606
# Processed batch 2213/2606
# Processed batch 2214/2606
# Processed batch 2215/2606
# Processed batch 2216/2606
# Processed batch 2217/2606
# Processed batch 2218/2606
# Processed batch 2219/2606
# Processed batch 2220/2606
# Processed batch 2221/2606
# Processed batch 2222/2606
# Processed batch 2223/2606
# Processed batch 2224/2606
# Processed batch 2225/2606
# Processed batch 2226/2606
# Processed batch 2227/2606
# Processed batch 2228/2606
# Processed batch 2229/2606
# Processed batch 2230/2606
# Processed batch 2231/2606
# Processed batch 2232/2606
# Processed batch 2233/2606
# Processed batch 2234/2606
# Processed batch 2235/2606
# Processed batch 2236/2606
# Processed batch 2237/2606
# Processed batch 2238/2606
# Processed batch 2239/2606
# Processed batch 2240/2606
# Processed batch 2241/2606
# Processed batch 2242/2606
# Processed batch 2243/2606
# Processed batch 2244/2606
# Processed batch 2245/2606
# Processed batch 2246/2606
# Processed batch 2247/2606
# Processed batch 2248/2606
# Processed batch 2249/2606
# Processed batch 2250/2606
# Processed batch 2251/2606
# Processed batch 2252/2606
# Processed batch 2253/2606
# Processed batch 2254/2606
# Processed batch 2255/2606
# Processed batch 2256/2606
# Processed batch 2257/2606
# Processed batch 2258/2606
# Processed batch 2259/2606
# Processed batch 2260/2606
# Processed batch 2261/2606
# Processed batch 2262/2606
# Processed batch 2263/2606
# Processed batch 2264/2606
# Processed batch 2265/2606
# Processed batch 2266/2606
# Processed batch 2267/2606
# Processed batch 2268/2606
# Processed batch 2269/2606
# Processed batch 2270/2606
# Processed batch 2271/2606
# Processed batch 2272/2606
# Processed batch 2273/2606
# Processed batch 2274/2606
# Processed batch 2275/2606
# Processed batch 2276/2606
# Processed batch 2277/2606
# Processed batch 2278/2606
# Processed batch 2279/2606
# Processed batch 2280/2606
# Processed batch 2281/2606
# Processed batch 2282/2606
# Processed batch 2283/2606
# Processed batch 2284/2606
# Processed batch 2285/2606
# Processed batch 2286/2606
# Processed batch 2287/2606
# Processed batch 2288/2606
# Processed batch 2289/2606
# Processed batch 2290/2606
# Processed batch 2291/2606
# Processed batch 2292/2606
# Processed batch 2293/2606
# Processed batch 2294/2606
# Processed batch 2295/2606
# Processed batch 2296/2606
# Processed batch 2297/2606
# Processed batch 2298/2606
# Processed batch 2299/2606
# Processed batch 2300/2606
# Processed batch 2301/2606
# Processed batch 2302/2606
# Processed batch 2303/2606
# Processed batch 2304/2606
# Processed batch 2305/2606
# Processed batch 2306/2606
# Processed batch 2307/2606
# Processed batch 2308/2606
# Processed batch 2309/2606
# Processed batch 2310/2606
# Processed batch 2311/2606
# Processed batch 2312/2606
# Processed batch 2313/2606
# Processed batch 2314/2606
# Processed batch 2315/2606
# Processed batch 2316/2606
# Processed batch 2317/2606
# Processed batch 2318/2606
# Processed batch 2319/2606
# Processed batch 2320/2606
# Processed batch 2321/2606
# Processed batch 2322/2606
# Processed batch 2323/2606
# Processed batch 2324/2606
# Processed batch 2325/2606
# Processed batch 2326/2606
# Processed batch 2327/2606
# Processed batch 2328/2606
# Processed batch 2329/2606
# Processed batch 2330/2606
# Processed batch 2331/2606
# Processed batch 2332/2606
# Processed batch 2333/2606
# Processed batch 2334/2606
# Processed batch 2335/2606
# Processed batch 2336/2606
# Processed batch 2337/2606
# Processed batch 2338/2606
# Processed batch 2339/2606
# Processed batch 2340/2606
# Processed batch 2341/2606
# Processed batch 2342/2606
# Processed batch 2343/2606
# Processed batch 2344/2606
# Processed batch 2345/2606
# Processed batch 2346/2606
# Processed batch 2347/2606
# Processed batch 2348/2606
# Processed batch 2349/2606
# Processed batch 2350/2606
# Processed batch 2351/2606
# Processed batch 2352/2606
# Processed batch 2353/2606
# Processed batch 2354/2606
# Processed batch 2355/2606
# Processed batch 2356/2606
# Processed batch 2357/2606
# Processed batch 2358/2606
# Processed batch 2359/2606
# Processed batch 2360/2606
# Processed batch 2361/2606
# Processed batch 2362/2606
# Processed batch 2363/2606
# Processed batch 2364/2606
# Processed batch 2365/2606
# Processed batch 2366/2606
# Processed batch 2367/2606
# Processed batch 2368/2606
# Processed batch 2369/2606
# Processed batch 2370/2606
# Processed batch 2371/2606
# Processed batch 2372/2606
# Processed batch 2373/2606
# Processed batch 2374/2606
# Processed batch 2375/2606
# Processed batch 2376/2606
# Processed batch 2377/2606
# Processed batch 2378/2606
# Processed batch 2379/2606
# Processed batch 2380/2606
# Processed batch 2381/2606
# Processed batch 2382/2606
# Processed batch 2383/2606
# Processed batch 2384/2606
# Processed batch 2385/2606
# Processed batch 2386/2606
# Processed batch 2387/2606
# Processed batch 2388/2606
# Processed batch 2389/2606
# Processed batch 2390/2606
# Processed batch 2391/2606
# Processed batch 2392/2606
# Processed batch 2393/2606
# Processed batch 2394/2606
# Processed batch 2395/2606
# Processed batch 2396/2606
# Processed batch 2397/2606
# Processed batch 2398/2606
# Processed batch 2399/2606
# Processed batch 2400/2606
# Processed batch 2401/2606
# Processed batch 2402/2606
# Processed batch 2403/2606
# Processed batch 2404/2606
# Processed batch 2405/2606
# Processed batch 2406/2606
# Processed batch 2407/2606
# Processed batch 2408/2606
# Processed batch 2409/2606
# Processed batch 2410/2606
# Processed batch 2411/2606
# Processed batch 2412/2606
# Processed batch 2413/2606
# Processed batch 2414/2606
# Processed batch 2415/2606
# Processed batch 2416/2606
# Processed batch 2417/2606
# Processed batch 2418/2606
# Processed batch 2419/2606
# Processed batch 2420/2606
# Processed batch 2421/2606
# Processed batch 2422/2606
# Processed batch 2423/2606
# Processed batch 2424/2606
# Processed batch 2425/2606
# Processed batch 2426/2606
# Processed batch 2427/2606
# Processed batch 2428/2606
# Processed batch 2429/2606
# Processed batch 2430/2606
# Processed batch 2431/2606
# Processed batch 2432/2606
# Processed batch 2433/2606
# Processed batch 2434/2606
# Processed batch 2435/2606
# Processed batch 2436/2606
# Processed batch 2437/2606
# Processed batch 2438/2606
# Processed batch 2439/2606
# Processed batch 2440/2606
# Processed batch 2441/2606
# Processed batch 2442/2606
# Processed batch 2443/2606
# Processed batch 2444/2606
# Processed batch 2445/2606
# Processed batch 2446/2606
# Processed batch 2447/2606
# Processed batch 2448/2606
# Processed batch 2449/2606
# Processed batch 2450/2606
# Processed batch 2451/2606
# Processed batch 2452/2606
# Processed batch 2453/2606
# Processed batch 2454/2606
# Processed batch 2455/2606
# Processed batch 2456/2606
# Processed batch 2457/2606
# Processed batch 2458/2606
# Processed batch 2459/2606
# Processed batch 2460/2606
# Processed batch 2461/2606
# Processed batch 2462/2606
# Processed batch 2463/2606
# Processed batch 2464/2606
# Processed batch 2465/2606
# Processed batch 2466/2606
# Processed batch 2467/2606
# Processed batch 2468/2606
# Processed batch 2469/2606
# Processed batch 2470/2606
# Processed batch 2471/2606
# Processed batch 2472/2606
# Processed batch 2473/2606
# Processed batch 2474/2606
# Processed batch 2475/2606
# Processed batch 2476/2606
# Processed batch 2477/2606
# Processed batch 2478/2606
# Processed batch 2479/2606
# Processed batch 2480/2606
# Processed batch 2481/2606
# Processed batch 2482/2606
# Processed batch 2483/2606
# Processed batch 2484/2606
# Processed batch 2485/2606
# Processed batch 2486/2606
# Processed batch 2487/2606
# Processed batch 2488/2606
# Processed batch 2489/2606
# Processed batch 2490/2606
# Processed batch 2491/2606
# Processed batch 2492/2606
# Processed batch 2493/2606
# Processed batch 2494/2606
# Processed batch 2495/2606
# Processed batch 2496/2606
# Processed batch 2497/2606
# Processed batch 2498/2606
# Processed batch 2499/2606
# Processed batch 2500/2606
# Processed batch 2501/2606
# Processed batch 2502/2606
# Processed batch 2503/2606
# Processed batch 2504/2606
# Processed batch 2505/2606
# Processed batch 2506/2606
# Processed batch 2507/2606
# Processed batch 2508/2606
# Processed batch 2509/2606
# Processed batch 2510/2606
# Processed batch 2511/2606
# Processed batch 2512/2606
# Processed batch 2513/2606
# Processed batch 2514/2606
# Processed batch 2515/2606
# Processed batch 2516/2606
# Processed batch 2517/2606
# Processed batch 2518/2606
# Processed batch 2519/2606
# Processed batch 2520/2606
# Processed batch 2521/2606
# Processed batch 2522/2606
# Processed batch 2523/2606
# Processed batch 2524/2606
# Processed batch 2525/2606
# Processed batch 2526/2606
# Processed batch 2527/2606
# Processed batch 2528/2606
# Processed batch 2529/2606
# Processed batch 2530/2606
# Processed batch 2531/2606
# Processed batch 2532/2606
# Processed batch 2533/2606
# Processed batch 2534/2606
# Processed batch 2535/2606
# Processed batch 2536/2606
# Processed batch 2537/2606
# Processed batch 2538/2606
# Processed batch 2539/2606
# Processed batch 2540/2606
# Processed batch 2541/2606
# Processed batch 2542/2606
# Processed batch 2543/2606
# Processed batch 2544/2606
# Processed batch 2545/2606
# Processed batch 2546/2606
# Processed batch 2547/2606
# Processed batch 2548/2606
# Processed batch 2549/2606
# Processed batch 2550/2606
# Processed batch 2551/2606
# Processed batch 2552/2606
# Processed batch 2553/2606
# Processed batch 2554/2606
# Processed batch 2555/2606
# Processed batch 2556/2606
# Processed batch 2557/2606
# Processed batch 2558/2606
# Processed batch 2559/2606
# Processed batch 2560/2606
# Processed batch 2561/2606
# Processed batch 2562/2606
# Processed batch 2563/2606
# Processed batch 2564/2606
# Processed batch 2565/2606
# Processed batch 2566/2606
# Processed batch 2567/2606
# Processed batch 2568/2606
# Processed batch 2569/2606
# Processed batch 2570/2606
# Processed batch 2571/2606
# Processed batch 2572/2606
# Processed batch 2573/2606
# Processed batch 2574/2606
# Processed batch 2575/2606
# Processed batch 2576/2606
# Processed batch 2577/2606
# Processed batch 2578/2606
# Processed batch 2579/2606
# Processed batch 2580/2606
# Processed batch 2581/2606
# Processed batch 2582/2606
# Processed batch 2583/2606
# Processed batch 2584/2606
# Processed batch 2585/2606
# Processed batch 2586/2606
# Processed batch 2587/2606
# Processed batch 2588/2606
# Processed batch 2589/2606
# Processed batch 2590/2606
# Processed batch 2591/2606
# Processed batch 2592/2606
# Processed batch 2593/2606
# Processed batch 2594/2606
# Processed batch 2595/2606
# Processed batch 2596/2606
# Processed batch 2597/2606
# Processed batch 2598/2606
# Processed batch 2599/2606
# Processed batch 2600/2606
# Processed batch 2601/2606
# Processed batch 2602/2606
# Processed batch 2603/2606
# Processed batch 2604/2606
# Processed batch 2605/2606
# Processed batch 2606/2606
# Shape of X_combined_adv: (2667523, 8)
# Adversarial samples saved to 'X_combined_adv.csv'.
#
# 📊 Evaluating Hybrid ANN + LSTM Model on Adversarial Samples...
#
# ✅ EVALUATION ON ADVERSARIAL SAMPLES
# Adversarial Loss       : 8.2415
# Adversarial Accuracy   : 0.2529
# Adversarial Precision  : 0.0000
# Adversarial Recall     : 0.0000
# Adversarial F1-Score   : 0.0000
# Adversarial Confusion Matrix:
# [[ 674549  232304]
#  [1760670       0]]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import tensorflow as tf

# --- Step 1: Combine original and adversarial data ---
X_total = np.concatenate([X_combined, X_combined_adv], axis=0)
y_total = np.concatenate([y_combined, y_combined], axis=0)  # Same labels for adversarial samples

# --- Step 2: Split into 80% train and 20% test ---
X_train_final, X_test_final, y_train_final, y_test_final = train_test_split(
    X_total, y_total, test_size=0.2, stratify=y_total, random_state=42
)

# --- Step 3: Reshape for LSTM input ---
X_train_final = X_train_final.reshape((X_train_final.shape[0], 1, X_train_final.shape[1]))
X_test_final = X_test_final.reshape((X_test_final.shape[0], 1, X_test_final.shape[1]))

# --- Step 4: Rebuild or Retrain the Hybrid ANN + LSTM Model ---
# If you already have the model architecture defined as `model`, just re-train it:
model.compile(optimizer='adam', loss='binary_crossentropy',
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

print("\n🔁 Training Hybrid ANN + LSTM on Clean + Adversarial Samples...")
history = model.fit(X_train_final, y_train_final, epochs=10, batch_size=512,
                    validation_split=0.1, shuffle=True)

# --- Step 5: Evaluate ---
print("\n📊 Evaluating on Test Set (Clean + Adversarial)...")
loss, accuracy, precision, recall = model.evaluate(X_test_final, y_test_final, verbose=0)
y_pred_final = (model.predict(X_test_final, verbose=0) > 0.5).astype("int32")
f1 = f1_score(y_test_final, y_pred_final)
conf_matrix = confusion_matrix(y_test_final, y_pred_final)

# --- Step 6: Print Results ---
print("\n✅ FINAL EVALUATION ON COMBINED DATA")
print(f"Loss           : {loss:.4f}")
print(f"Accuracy       : {accuracy:.4f}")
print(f"Precision      : {precision:.4f}")
print(f"Recall         : {recall:.4f}")
print(f"F1-Score       : {f1:.4f}")
print("\nConfusion Matrix:")
print(conf_matrix)
# Out:
# 🔁 Training Hybrid ANN + LSTM on Clean + Adversarial Samples...
# Epoch 1/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 49s 6ms/step - accuracy: 0.9302 - loss: 0.2421 - precision: 0.9112 - recall: 0.9908 - val_accuracy: 0.9648 - val_loss: 0.1517 - val_precision: 0.9495 - val_recall: 1.0000
# Epoch 2/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step - accuracy: 0.9476 - loss: 0.1811 - precision: 0.9289 - recall: 0.9969 - val_accuracy: 0.9636 - val_loss: 0.1406 - val_precision: 0.9479 - val_recall: 1.0000
# Epoch 3/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 81s 5ms/step - accuracy: 0.9513 - loss: 0.1696 - precision: 0.9332 - recall: 0.9976 - val_accuracy: 0.9636 - val_loss: 0.1299 - val_precision: 0.9516 - val_recall: 0.9956
# Epoch 4/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.9516 - loss: 0.1660 - precision: 0.9335 - recall: 0.9977 - val_accuracy: 0.9623 - val_loss: 0.1304 - val_precision: 0.9543 - val_recall: 0.9904
# Epoch 5/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 41s 5ms/step - accuracy: 0.9515 - loss: 0.1645 - precision: 0.9335 - recall: 0.9977 - val_accuracy: 0.9664 - val_loss: 0.1260 - val_precision: 0.9517 - val_recall: 1.0000
# Epoch 6/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9517 - loss: 0.1626 - precision: 0.9336 - recall: 0.9977 - val_accuracy: 0.9590 - val_loss: 0.1491 - val_precision: 0.9416 - val_recall: 1.0000
# Epoch 7/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 42s 5ms/step - accuracy: 0.9519 - loss: 0.1615 - precision: 0.9340 - recall: 0.9977 - val_accuracy: 0.9684 - val_loss: 0.1190 - val_precision: 0.9550 - val_recall: 0.9995
# Epoch 8/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 39s 5ms/step - accuracy: 0.9516 - loss: 0.1592 - precision: 0.9339 - recall: 0.9973 - val_accuracy: 0.9679 - val_loss: 0.1223 - val_precision: 0.9538 - val_recall: 1.0000
# Epoch 9/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 43s 5ms/step - accuracy: 0.9518 - loss: 0.1583 - precision: 0.9341 - recall: 0.9973 - val_accuracy: 0.9645 - val_loss: 0.1225 - val_precision: 0.9491 - val_recall: 1.0000
# Epoch 10/10
# 7503/7503 ━━━━━━━━━━━━━━━━━━━━ 40s 5ms/step - accuracy: 0.9517 - loss: 0.1585 - precision: 0.9340 - recall: 0.9973 - val_accuracy: 0.9572 - val_loss: 0.1291 - val_precision: 0.9561 - val_recall: 0.9802
#
# 📊 Evaluating on Test Set (Clean + Adversarial)...
#
# ✅ FINAL EVALUATION ON COMBINED DATA
# Loss           : 0.1282
# Accuracy       : 0.9576
# Precision      : 0.9566
# Recall         : 0.9802
# F1-Score       : 0.9683
#
# Confusion Matrix:
# [[331457  31284]
#  [ 13920 690349]]

# %%
# Visualization
# Figure 1: Bar Plots
plt.figure(figsize=(18, 5))
plt.suptitle('Performance Comparison for Hybrid ANN+LSTM Model', fontsize=16)

# Original Test Set
accuracy_orig = accuracy_score(y_test, y_test_pred) * 100
precision_orig = precision_score(y_test, y_test_pred) * 100
recall_orig = recall_score(y_test, y_test_pred) * 100

x = np.arange(1)
width = 0.2
plt.subplot(1, 3, 1)
bars1 = plt.bar(x - width, [accuracy_orig], width, label='Accuracy', color='blue')
bars2 = plt.bar(x, [precision_orig], width, label='Precision', color='red')
bars3 = plt.bar(x + width, [recall_orig], width, label='Recall', color='green')
plt.xlabel("Model")
plt.ylabel("Percentage")
plt.title("Original Test Set")
plt.xticks(x)
plt.xticks(x, ["Hybrid"])
plt.ylim(0, 100)
for bars, values in [(bars1, [accuracy_orig]), (bars2, [precision_orig]), (bars3, [recall_orig])]:
    for bar, value in zip(bars, values):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{value:.2f}', ha='center', va='bottom', fontsize=9)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adversarial Dataset
accuracy_adv = accuracy_score(y_combined, y_adv_pred) * 100
precision_adv = precision_score(y_combined,y_adv_pred) * 100
recall_adv = recall_score(y_combined, y_adv_pred) * 100

plt.subplot(1, 3, 2)
bars1 = plt.bar(x - width, [accuracy_adv], width, label='Accuracy', color='blue')
bars2 = plt.bar(x, [precision_adv], width, label='Precision', color='red')
bars3 = plt.bar(x + width, [recall_adv], width, label='Recall', color='green')
plt.xlabel("Model")
plt.ylabel("Percentage")
plt.title("Adversarial Dataset")
plt.xticks(x)
plt.xticks(x, ["Hybrid"])
plt.ylim(0, 100)
for bars, values in [(bars1, [accuracy_adv]), (bars2, [precision_adv]), (bars3, [recall_adv])]:
    for bar, value in zip(bars, values):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{value:.2f}', ha='center', va='bottom', fontsize=9)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Combined Dataset
accuracy_combined = accuracy_score(y_test_final, y_pred_final) * 100
precision_combined = precision_score(y_test_final, y_pred_final) * 100
recall_combined = recall_score(y_test_final, y_pred_final) * 100

plt.subplot(1, 3, 3)
bars1 = plt.bar(x - width, [accuracy_combined], width, label='Accuracy', color='blue')
bars2 = plt.bar(x, [precision_combined], width, label='Precision', color='red')
bars3 = plt.bar(x + width, [recall_combined], width, label='Recall', color='green')
plt.xlabel("Model")
plt.ylabel("Percentage")
plt.title("Combined Dataset")
plt.xticks(x)
plt.xticks(x, ["Hybrid"])
plt.ylim(0, 100)
for bars, values in [(bars1, [accuracy_combined]), (bars2, [precision_combined]), (bars3, [recall_combined])]:
    for bar, value in zip(bars, values):
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, height, f'{value:.2f}', ha='center', va='bottom', fontsize=9)
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# Figure 2: Confusion Matrices
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.heatmap(test_conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Original Test Set')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(1, 3, 2)
sns.heatmap(adv_cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Adversarial Dataset')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.subplot(1, 3, 3)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.title('Confusion Matrix - Combined Dataset')
plt.xlabel('Predicted')
plt.ylabel('Actual')

plt.tight_layout()
plt.show()

# Figure 3: ROC Curves
plt.figure(figsize=(8, 6))

# Original Test Set ROC
y_pred_prob_hybrid = model.predict(X_test_lstm, verbose=0)
fpr_orig, tpr_orig, _ = roc_curve(y_test, y_test_pred)
auc_orig = roc_auc_score(y_test, y_test_pred)
plt.plot(fpr_orig, tpr_orig, label=f'Original (AUC = {auc_orig:.2f})', color='blue')

# Adversarial Dataset ROC
y_pred_prob_adv = model.predict(X_combined_adv_lstm, verbose=0)
fpr_adv, tpr_adv, _ = roc_curve(y_combined, y_adv_pred)
auc_adv = roc_auc_score(y_combined, y_adv_pred)
plt.plot(fpr_adv, tpr_adv, label=f'Adversarial (AUC = {auc_adv:.2f})', color='red')

# Combined Dataset ROC
y_pred_prob_combined = model.predict(X_test_final, verbose=0)
fpr_combined, tpr_combined, _ = roc_curve(y_test_final, y_pred_final)
auc_combined = roc_auc_score(y_test_final, y_pred_final)
plt.plot(fpr_combined, tpr_combined, label=f'Combined (AUC = {auc_combined:.2f})', color='green')

plt.title('ROC Curves for Hybrid ANN+LSTM Model')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='best')
plt.grid(True)
plt.tight_layout()
plt.show()
